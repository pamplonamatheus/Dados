# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy import stats
import math
from random import shuffle
import matplotlib.mlab as mlab

print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Matheus\Documents\GitHub\Dados\projeto5

# %%
suic = pd.read_excel('suicidios.xlsx',sep=',')
urb = pd.read_excel('urban.xlsx',sep=',')
diox = pd.read_excel('diox.xlsx',sep=',')

# %%
diox
# Out:
#             CO2 emission total         V2004
# 0                     Abkhazia           NaN
# 1                  Afghanistan  7.333333e+02
# 2        Akrotiri and Dhekelia           NaN
# 3                      Albania  4.114000e+03
# 4                      Algeria  8.948500e+04
# 5               American Samoa           NaN
# 6                      Andorra  5.646667e+02
# 7                       Angola  1.879167e+04
# 8                     Anguilla  4.400000e+01
# 9          Antigua and Barbuda  4.070000e+02
# 10                   Argentina  1.561560e+05
# 11                     Armenia  3.644667e+03
# 12                       Aruba  2.258667e+03
# 13                   Australia  3.491913e+05
# 14                     Austria  7.185933e+04
# 15                  Azerbaijan  3.208700e+04
# 16                     Bahamas  2.152333e+03
# 17                     Bahrain  1.750833e+04
# 18                  Bangladesh  3.979067e+04
# 19                    Barbados  1.294333e+03
# ...

# %%
diox=diox[~np.isnan(diox.V2004)]
urb=urb[~np.isnan(urb.V2004)]
suic=suic[~np.isnan(suic.V2004)]
#dados=dados[~np.isnan(dados.MortalidadeAbaixo5)]
#dados=dados[~np.isnan(dados.IDH)]
suic.shape
# Out:
# (192, 2)

# %%
diox.shape
# Out:
# (210, 2)

# %%
plt.subplot(121)
plt.scatter( urb.V2004,diox.V2004, alpha=0.7, c='yellow')
plt.title('QQplot 1800 e 2000')
plt.xlabel('1800')
plt.ylabel('2000')
                
plt.subplot(122)
plt.scatter( urb.V2004,np.log(diox.V2004), alpha=0.7, c='yellow')
plt.title('QQplot 1800 e 2000')
plt.xlabel('1800')
plt.ylabel('2000')
#plt.plot((7,90),(7,90))
#plt.ylim(15,90)
#plt.xlim(15,90)



plt.tight_layout(1)
